# %% [markdown]
# # Циклы. Домашнее задание
#
# ### Цели задания
# Закрепить на практике применение циклов for, while и использование команд break, continue, pass.
#
# ### Что нужно сделать
# Скачайте файл с заданием, откройте его через Jupyter Notebook и выполните задачи.
#
# ### Что оценивается
# Для каждой задачи:
# - программа выполняет все требуемые действия;
# - результаты вычислений и операций корректны;
# - вывод производится в том виде, который описан в задаче;
# - переменные названы информативно.
#
# ## Как отправить задание на проверку
# Выполните задачи, сохраните изменения при помощи опции Save and Checkpoint из вкладки меню File или кнопки Save and Checkpoint на панели инструментов. Отправьте через форму ниже итоговый файл Jupyter Notebook .ipynb или ссылку на него.

# %% [markdown]
# 1. Напишите цикл, который выводит на печать все високосные годы, начиная с 2020 и заканчивая 2050.

# %%
month_start = 2020
month_end   = 2050
count       = 0

for year in range(month_start, month_end + 1):
    if year % 4 == 0:
        print(str(year),"год - високосный")
        count += 1
    else:
        continue
        
print("За период с", str(month_start), "по", str(month_end),"-", str(count), "високосных годов.")
# Out:
# 2020 год - високосный
# 2024 год - високосный
# 2028 год - високосный
# 2032 год - високосный
# 2036 год - високосный
# 2040 год - високосный
# 2044 год - високосный
# 2048 год - високосный
# За период с 2020 по 2050 - 8 високосных годов.

# %% [markdown]
# 2. Студент Джонсон поступил в университет и взял кредит на 120 тысяч долларов под 6% годовых. Все шесть лет учёбы в бакалавриате и магистратуре он не сможет выплачивать кредит и процент будет прибавляться к основному кредиту. Напишите программу, которая посчитает, сколько студент Джонсон должен будет банку к концу своего обучения.

# %%
# Начальная сумма
loan = 120000
rate = 6 

universaty_period = 6


for year in range(1, universaty_period + 1):
    loan += (loan * (rate / 100))
    print("За", str(year) + "-й год сумма составит:", str(round(loan, 2)))

print("К концу обучения студент Джонсон будет должен банку:", str(round(loan, 2)))
# Out:
# За 1-й год сумма составит: 127200.0
# За 2-й год сумма составит: 134832.0
# За 3-й год сумма составит: 142921.92
# За 4-й год сумма составит: 151497.24
# За 5-й год сумма составит: 160587.07
# За 6-й год сумма составит: 170222.29
# К концу обучения студент Джонсон будет должен банку: 170222.29

# %% [markdown]
# 3. Вспомним задачку о [зёрнах на шахматной доске](https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BE_%D0%B7%D1%91%D1%80%D0%BD%D0%B0%D1%85_%D0%BD%D0%B0_%D1%88%D0%B0%D1%85%D0%BC%D0%B0%D1%82%D0%BD%D0%BE%D0%B9_%D0%B4%D0%BE%D1%81%D0%BA%D0%B5). На первую клетку кладётся одно зерно, на вторую — два зерна, на третью — четыре, затем — восемь. С каждой клеткой количество зёрен увеличивается в два раза.
#
# Напишите цикл, который выводил бы на печать порядковый номер клетки и количество зёрен на ней до тех пор, пока их количество на одной клетке не превысит 100 тысяч.

# %%
for cell in range(65):
    number_grains = 2 ** cell
    print("На", str(cell + 1), "ячейке,", str(number_grains), "зерен")
    
    if number_grains > 100000:
        break
        
print("_____________________________")
print("На ячейке", str(cell + 1), "-", str(number_grains), "зерен")
# Out:
# На 1 ячейке, 1 зерен
# На 2 ячейке, 2 зерен
# На 3 ячейке, 4 зерен
# На 4 ячейке, 8 зерен
# На 5 ячейке, 16 зерен
# На 6 ячейке, 32 зерен
# На 7 ячейке, 64 зерен
# На 8 ячейке, 128 зерен
# На 9 ячейке, 256 зерен
# На 10 ячейке, 512 зерен
# На 11 ячейке, 1024 зерен
# На 12 ячейке, 2048 зерен
# На 13 ячейке, 4096 зерен
# На 14 ячейке, 8192 зерен
# На 15 ячейке, 16384 зерен
# На 16 ячейке, 32768 зерен
# На 17 ячейке, 65536 зерен
# На 18 ячейке, 131072 зерен
# _____________________________
# На ячейке 18 - 131072 зерен

# %% [markdown]
# 4. Напишите программу, которая проверяла бы все числа от 0 до 30. Если число делится на два, его нужно напечатать. Но если число делится и на четыре, его нужно пропустить.

# %%
for number in range(31):
    if number % 4 == 0:
        continue
    if number % 2 == 0:
        print("Число", str(number),"делится на 2")
# Out:
# Число 2 делится на 2
# Число 6 делится на 2
# Число 10 делится на 2
# Число 14 делится на 2
# Число 18 делится на 2
# Число 22 делится на 2
# Число 26 делится на 2
# Число 30 делится на 2

# %% [markdown]
# 5. Напишите программу, которая бесконечно запрашивает на ввод целое число. Если оно делится на три, то выводится на печать. Если делится на пять, то  на печать выводится его квадрат. Квадрат пишется даже для тех чисел, которые делятся на три. Если число делится на семь, нужно вывести на печать «дурак совсем» и прервать выполнение программы. Во всех остальных случаях программа должна снова запросить число на ввод.

# %%
while True:
    number = int(input("Введите целое число:"))
    if number % 3 == 0:
        print("Число", str(number), "делится на три. Его квадрат =", str(number ** 2))
        
    if number % 5 == 0:
        print("Число", str(number), "делится на пять. Его квадрат =", str(number ** 2))
        
    if number % 7 == 0:
        print("Дурак совсем...")
        break
# Out:
# Введите целое число:45
# Число 45 делится на три. Его квадрат = 2025
# Число 45 делится на пять. Его квадрат = 2025
# Введите целое число:23
# Введите целое число:29
# Введите целое число:56
# Дурак совсем...
